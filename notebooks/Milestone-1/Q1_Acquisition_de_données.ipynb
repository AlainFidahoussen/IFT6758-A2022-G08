# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# To load the environment variable defined in the .env file
from dotenv import load_dotenv
load_dotenv();

# %%
import os
import src.data.NHLDataManager as DataManager

# %%
data_manager = DataManager.NHLDataManager()
data_manager.data_dir
# Out:
# '/mnt/d/GitHub/IFT6758-A2022-G08/data'

# %%
seasons_year = [2016, 2017]
data_manager.download_data(seasons_year=seasons_year, season_type="Regular")
data_manager.download_data(seasons_year=seasons_year, season_type="Playoffs")
# Out:
# ...
#   0%|          | 0/105 [00:00<?, ?it/s]

# %%
season_year = 2016
season_type = "Regular"

data_season = data_manager.load_data(season_year=season_year, season_type=season_type)
len(data_season.keys())
# Out:
#   0%|          | 0/1230 [00:00<?, ?it/s]
# 1230

# %%
os.listdir(os.path.join(os.environ['NHL_DATA_DIR'], 'raw', str(season_year), season_type))[0:10]
# Out:
# ['2016020001.json',
#  '2016020002.json',
#  '2016020003.json',
#  '2016020004.json',
#  '2016020005.json',
#  '2016020006.json',
#  '2016020007.json',
#  '2016020008.json',
#  '2016020009.json',
#  '2016020010.json']

# %%
# Load a specific game
season_year = 2016
season_type = "Regular"
game_number = 12

data_game = data_manager.load_game(season_year=season_year, season_type=season_type, game_number=game_number)
data_game
# Out:
# {'copyright': 'NHL and the NHL Shield are registered trademarks of the National Hockey League. NHL and NHL team marks are the property of the NHL and its teams. © NHL 2022. All Rights Reserved.',
#  'gamePk': 2016020012,
#  'link': '/api/v1/game/2016020012/feed/live',
#  'metaData': {'wait': 10, 'timeStamp': '20170920_083502'},
#  'gameData': {'game': {'pk': 2016020012, 'season': '20162017', 'type': 'R'},
#   'datetime': {'dateTime': '2016-10-14T00:00:00Z',
#    'endDateTime': '2016-10-14T02:50:28Z'},
#   'status': {'abstractGameState': 'Final',
#    'codedGameState': '7',
#    'detailedState': 'Final',
#    'statusCode': '7',
#    'startTimeTBD': False},
#   'teams': {'away': {'id': 12,
#     'name': 'Carolina Hurricanes',
#     'link': '/api/v1/teams/12',
#     'venue': {'id': 5066,
#      'name': 'PNC Arena',
#      'link': '/api/v1/venues/5066',
#      'city': 'Raleigh',
#      'timeZone': {'id': 'America/New_York', 'offset': -4, 'tz': 'EDT'}},
#     'abbreviation': 'CAR',
# ...
